# %% [markdown]
# # Блок 1.
#
# С помощью symPy найдите полиномы, описывающие данные наборы точек. Затем проведите полное исследование каждого полученного полинома: проверьте четность/нечетность, найдите нули, промежутки знакопостоянства. Постройте их графики. С помощью изменения промежутка для х добейтесь того, чтобы все нули были отображены на графике функции. <br><br><br>
# а) $(-4; -4268), (-3; -1227), (-1; -17), (1; 17), (3; 1227), (4; 4268)$<br><br>
# б)$ (-4; -16729), (-3; -3999), (-1; 5), (1; 1), (3; 4005), (4; 16735)$

# %%
from sympy import *

a0, a1, a2, a3, a4, a5 = symbols('a0, a1, a2, a3, a4, a5')

# %%
eq1_lp = (-4)**5*a5 + (-4)**4*a4 + (-4)**3*a3 + (-4)**2*a2 + (-4)**1*a1 + a0 + 4268
eq2_lp = (-3)**5*a5 + (-3)**4*a4 + (-3)**3*a3 + (-3)**2*a2 + (-3)**1*a1 + a0 + 1227
eq3_lp = (-1)**5*a5 + (-1)**4*a4 + (-1)**3*a3 + (-1)**2*a2 + (-1)**1*a1 + a0 + 17
eq4_lp = (1)**5*a5 + (1)**4*a4 + (1)**3*a3 + (1)**2*a2 + (1)**1*a1 + a0 - 17
eq5_lp = (3)**5*a5 + (3)**4*a4 + (3)**3*a3 + (3)**2*a2 + (3)**1*a1 + a0 - 1227
eq6_lp = (4)**5*a5 + (4)**4*a4 + (4)**3*a3 + (4)**2*a2 + (4)**1*a1 + a0 - 4268

nonlinsolve([eq1_lp, eq2_lp, eq3_lp, eq4_lp, eq5_lp, eq6_lp], [a5, a4, a3, a2, a1, a0])
# Out:
# FiniteSet((3, 0, 19, 0, -5, 0))

# %%
x = Symbol('x')
f = 3*x**5 + 19*x**3 - 5*x
f
# Out:
# 3*x**5 + 19*x**3 - 5*x

# %%
f1 = f.subs(x, -x)
f1
# Out:
# -3*x**5 - 19*x**3 + 5*x

# %% [markdown]
# Т.е. функция $3𝑥^5+19𝑥^3−5𝑥$ - нечетная.
#
# Найдем нули функции $3𝑥^5+19𝑥^3−5𝑥$:

# %%
solve(f)
# Out:
# [0,
#  -I*sqrt(19/6 + sqrt(421)/6),
#  I*sqrt(19/6 + sqrt(421)/6),
#  -sqrt(-19/6 + sqrt(421)/6),
#  sqrt(-19/6 + sqrt(421)/6)]

# %%
# Функция больше нуля:

solve_univariate_inequality(f>0, x)
# Out:
# ((x < oo) & (sqrt(-19/6 + sqrt(421)/6) < x)) | ((x < 0) & (-sqrt(-19/6 + sqrt(421)/6) < x))

# %%
# Функция больше нуля:

solve_univariate_inequality(f<0, x)
# Out:
# ((0 < x) & (x < sqrt(-19/6 + sqrt(421)/6))) | ((-oo < x) & (x < -sqrt(-19/6 + sqrt(421)/6)))

# %%
plot(f, (x, -0.75, 0.75))

# %% [markdown]
# Еще два нуля функции не отображены, так как они - мнимые.

# %% [markdown]
# # Блок 2.

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = Symbol('x')

# %% [markdown]
# ## 1.
# ### Получите значение MSE меньшее 5.

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([2, -4, 1, 8, 21, 40, 47, 65, 75, 92])
    plt.xlim(-6, 10)
    plt.ylim(-1, 100)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f1 = 48 * x**2 - 128 * x + 83
f1
# Out:
#     2
# 48*x  - 128*x + 83

# %%
print_points_ands_function1(f1)
# Out:
# MSE = 93691.3

# %%
f1_new = f1.subs(x, x+2.2)
f1_new
# Out:
#                                          2
# -128*x + 232.32*(0.454545454545455*x + 1)  - 198.6

# %%
expand(f1_new)
# Out:
#       2
# 48.0*x  + 83.2*x + 33.72

# %%
print_points_ands_function1(f1_new/18-2)
# Out:
# MSE = 3.707501234567892

# %% [markdown]
# ## 2.
# ### Получите значение MSE меньшее 35.

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-31, -9, 4, -1, 9, 24, 47, 92, 120, 170])
    plt.xlim(-3, 6)
    plt.ylim(-35, 200)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f2 = 4 * x**3 + 30 * x**2 + 74 * x + 62
f2
# Out:
#    3       2
# 4*x  + 30*x  + 74*x + 62

# %%
print_points_ands_function2(f2)
# Out:
# MSE = 607200.2

# %%
f2_new = f2.subs(x, x-3)
f2_new
# Out:
#                 3             2
# 74*x + 4*(x - 3)  + 30*(x - 3)  - 160

# %%
expand(f2_new)
# Out:
#    3      2
# 4*x  - 6*x  + 2*x + 2

# %%
print_points_ands_function2(f2_new/2)
# Out:
# MSE = 34.725

# %% [markdown]
# ## 3.
# ### Получите значение MSE меньшее 3300.

# %%
def print_points_ands_function3(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([60, 25, 4, -0, -57, -195, -295, -540, -700, -760])
    plt.xlim(-10, 6)
    plt.ylim(-850, 100)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f3 = -36 * x**3 - 756 * x**2 - 5334 * x - 12636
f3
# Out:
#       3        2
# - 36*x  - 756*x  - 5334*x - 12636

# %%
print_points_ands_function3(f3)
# Out:
# MSE = 1346344545.35

# %%
f3_new = f3.subs(x, x-7)
f3_new
# Out:
#                     3              2
# -5334*x - 36*(x - 7)  - 756*(x - 7)  + 24702

# %%
expand(f3_new)
# Out:
#       3
# - 36*x  - 42*x + 6

# %%
print_points_ands_function3(f3_new/6)
# Out:
# MSE = 3295.5625

# %% [markdown]
# ## 4.
# ### Получите значение MSE меньшее 25.

# %%
def print_points_ands_function4(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-42, -37, -23, -36, -45, -80, -83, -110, -131, -155])
    plt.xlim(-4, 20)
    plt.ylim(-160, -10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f4 = - 5 / 4 * x**2 + 25 * x - 152
f4
# Out:
#         2
# - 1.25*x  + 25*x - 152

# %%
print_points_ands_function4(f4)
# Out:
# MSE = 9143.51953125

# %%
f4_new = f4.subs(x, x+10)
f4_new
# Out:
#                     2
# 25*x - 1.25*(x + 10)  + 98

# %%
expand(f4_new)
# Out:
#         2
# - 1.25*x  - 27.0

# %%
print_points_ands_function4(f4_new*4+78)
# Out:
# MSE = 23.6125
