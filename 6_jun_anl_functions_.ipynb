# %% [markdown]
# # Функции
# ### Домашнее задание

# %% [markdown]
# #### 1.
# Почему возникла ошибка? Объясните и исправьте.

# %%
def factorial(n):
    f = 1
    for i in range(2, n + 1):
        f = f * i
    return f
    print(f)

factorial(3)
# Out:
# 6

# %% [markdown]
# **Объяснение:**
# <br>Инициализация переменной f происходит в функции factorial, а вызов печати этой переменной происходит за пределами этой функции. То есть для печати данная переменная не инициализирована.<br>

# %% [markdown]
# #### 2.
# Почему переменная S после запуска функции сохранила значение ноль?

# %%
S = 0
def sum(n, m):
    S = n + m
    return S

print(sum(3, 4))
print(S)
# Out:
# 7
# 0

# %% [markdown]
# **Объяснение:**
# <br>Потому что значения переменной S, отличные от нуля, находятся только внутри функции sum()<br>

# %% [markdown]
# #### 3.
# Почему возникла ошибка? Объясните и исправьте, чтобы функция могла работать с данными на входе в примере с `res`.

# %%
def mult(q, w, e, r, t, y):
    return q + w + e + r + t + y
res = mult(1, 2, 3, 4, 5, 6)

# %% [markdown]
# **Объяснение:**
# <br>Данная функция принимает 6 явных параметров, а при вызове функции ей передаются 6 позиционных *параметров*<br>

# %% [markdown]
# #### 4.
# Почему возникла ошибка? Объясните и исправьте, чтобы функция могла работать с данными на входе в примере.

# %%
def power(a, s, *, d):
    res = a ** s ** d
    print(res)
    
power(5, 6, d = 4)
# Out:
# ...

# %% [markdown]
# **Объяснение:**
# <br>Данная функция принимает 2 позоционных аргумента и один явный, а ей подается один явный и два позиционный. Нужно изменить последовательность принимаемых функции аргументов.<br>

# %% [markdown]
# #### 5.
# Почему возникла ошибка? Объясните и исправьте, чтобы функция могла работать с данными на входе в примере.

# %%
def mult2(*args):
    res = 1
    for i in args:
        res += i
    return res

List = [1, 2, 3, 4, 5, 6, 7]
print(mult2(*List))
# Out:
# 29

# %% [markdown]
# **Объяснение:**
# <br>Изначально функция готова принимать произвольное число параметров, а в нее передается только список без распаковки.<br>

# %% [markdown]
# #### 6.
# Почему возникла ошибка? Объясните и исправьте.

# %%
def some_function(*args):
    pass

# %% [markdown]
# **Объяснение:**
# <br>Изначально функция готова принимать два позиционных параметра(a и b), произвольное число именованных параметров (**kwargs) и просто произвольное число любых параметров (*args). Масло масляное.<br>

# %% [markdown]
# #### 7.
# Почему не был создан новый список при повторном запуске функции? Объясните и исправьте.

# %%
def to_buy(*new_items, shopping_list = None):
    if shopping_list == None:
        shopping_list = []
    shopping_list.append(new_items)
    return shopping_list

monday = to_buy('яблоки', 'молоко', 'хлеб')
print(*monday)

tuesday = to_buy('груши', 'йогурт', 'мясо')
print(*tuesday)
# Out:
#   File "<ipython-input-10-68a013f11614>", line 5
#     return (*shopping_list)
#            ^
# SyntaxError: can't use starred expression here

# %% [markdown]
# **Объяснение:**
# <br>Новый список не был создан потому, что параметры по умолчанию вычисляются один раз.<br>

# %% [markdown]
# #### 8.
# Измените данную функцию так, чтобы она распечатывала названия продуктов из словаря в примере.

# %%
def print_all(**kwargs):
    
    print(kwargs)
        
print_all(**{'1' : 'яблоки', '2' :'молоко', '3' : 'хлеб', '4' : 'груши', '5' : 'йогурт', '6' : 'мясо'})
# Out:
# {'1': 'яблоки', '2': 'молоко', '3': 'хлеб', '4': 'груши', '5': 'йогурт', '6': 'мясо'}

# %% [markdown]
# #### 9.
# Программисты договорились, что переменные такого рода являются.. *(вопрос из лекции)*

# %%
TOKEN = ...

# %% [markdown]
# **Ответ:**
# <br>
# Константа
# <br>

# %% [markdown]
# #### 10.
# Напишите функцию, которая с помощью рекурсии считает сумму последовательности с шагом m. В качестве аргументов подаются целые положительные числа n (последний элемент последовательности) и m (шаг последовательности). Считается, что все члены последовательности являются целыми положительными числами.
#
# Пример:
#
# ```
# sum_of_seq(5, 1)
# 15
#
# sum_of_seq(5, 9)
# 5
#
# sum_of_seq(8, 2)
# 20
# ```

# %%
### YOUR CODE HERE ###
def sum_of_seq(n, m):
    if n>=1:
        return n + sum_of_seq(n - m, m)
    else:
        return 0

sum_of_seq(24,3)
# Out:
# 108

# %% [markdown]
# #### 11.
# Напишите функцию, которая возводит число в положительную степень с помощью рекурсии. В качестве аргументов подаются целые положительные числа n (число) и m (степень).

# %%
### YOUR CODE HERE ###
def recurs(b, n):
    if n==0:
        return 1
    return b*recurs(b, n-1)

recurs(2, 9)
# Out:
# 512

# %% [markdown]
# #### 12.
# Напишите функцию, которая возводит число в отрицательную степень число с помощью рекурсии. В качестве аргументов подаются целое положительное число n (число) и целое отрицательное число m (степень).

# %%
### YOUR CODE HERE ###
def minus_recurs(b, n):
    if n==0:
        return 1
    return (1/b)*(1/minus_recurs(b, n+1))

minus_recurs(4, -2)
# Out:
# 1.0

# %% [markdown]
# #### 13.
#
# Напишите функцию, которая находит число Фиббоначи по его номеру. В качестве аргумента подается целое положительное число n (число).

# %%
### YOUR CODE HERE ###

def fibonacci(n):
    if n in (1, 2):
        return 1
    return fibonacci(n - 1) + fibonacci(n - 2)

print(fibonacci(13))
# Out:
# 233
